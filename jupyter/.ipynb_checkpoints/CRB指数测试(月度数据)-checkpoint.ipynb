# %%
import os
import sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)
from windHelper import WindHelper
from factorModel.factorValidator import *
from factorModel.factorEvent import *
from datetime import *
beginDate = datetime(2014, 1, 1)
endDate = datetime(2017, 8, 22)

# %% [markdown]
# # 获取因子的序列

# %%
para = "close"
codeList=["CRBSA.RB"]
factor_df = WindHelper.getMultiTimeSeriesDataFrame(codeList=codeList, beginDate=beginDate, endDate=endDate, para=para)
factor_df = factor_df.dropna()
# 日度数据转为月度数据
asset_df = asset_df.resample("M").last()
len(df)
asset_series = factor_df[(codeList[0]).lower() + "_close"]
asset_series.head()
# Out:
# trade_date
# 2014-01-02    455.35
# 2014-01-03    455.69
# 2014-01-06    456.76
# 2014-01-07    456.63
# 2014-01-08    455.47
# Name: crbsa.rb_close, dtype: float64

# %% [markdown]
# # 获取资产价格序列

# %%
para = "close"
codeList=["060E.CS"]
asset_df = WindHelper.getMultiTimeSeriesDataFrame(codeList=codeList, beginDate=beginDate, endDate=endDate, para=para)
asset_df = df.dropna()

asset_series = asset_df[(codeList[0]).lower() + "_" + para]
asset_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-142-40ec1cc773e9> in <module>()
#       6 asset_df = asset_df.resample("M").last()
#       7 len(df)
# ----> 8 asset_series = asset_df[(codeList[0]).lower() + "_" + para]
#       9 asset_df.head()
#
# C:\dev_env\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# C:\dev_env\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# C:\dev_env\Anaconda2\lib\site-packages\pandas\core\generic.pyc in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# C:\dev_env\Anaconda2\lib\site-packages\pandas\core\internals.pyc in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\dev_env\Anaconda2\lib\site-packages\pandas\indexes\base.pyc in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: '060e.cs_close'

# %% [markdown]
# # 观察7-10年国开财富指数和CRB的关系

# %%
import pandas_highcharts
from pandas_highcharts.display import display_charts
import matplotlib.pyplot as plt
df = asset_df.join(factor_df, how="left").fillna(inplace=True, method="ffill")
df
# display_charts(df, chart_type="stock",secondary_y='crbsa.rb_close', title="CRB测试")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-139-f8a0986164e7> in <module>()
#       2 from pandas_highcharts.display import display_charts
#       3 import matplotlib.pyplot as plt
# ----> 4 df = asset_df.join(factor_df, how="left").fillna(inplace=True, method="ffill")
#       5 df
#       6 # display_charts(df, chart_type="stock",secondary_y='crbsa.rb_close', title="CRB测试")
#
# C:\dev_env\Anaconda2\lib\site-packages\pandas\core\frame.pyc in join(self, other, on, how, lsuffix, rsuffix, sort)
#    4553         # For SparseDataFrame's benefit
#    4554         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 4555                                  rsuffix=rsuffix, sort=sort)
#    4556
#    4557     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# C:\dev_env\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    4567             return merge(self, other, left_on=on, how=how,
#    4568                          left_index=on is None, right_index=True,
# -> 4569                          suffixes=(lsuffix, rsuffix), sort=sort)
#    4570         else:
#    4571             if on is not None:
#
# C:\dev_env\Anaconda2\lib\site-packages\pandas\tools\merge.pyc in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      60                          right_index=right_index, sort=sort, suffixes=suffixes,
#      61                          copy=copy, indicator=indicator)
# ---> 62     return op.get_result()
#      63 if __debug__:
#      64     merge.__doc__ = _merge_doc % '\nleft : DataFrame'
#
# C:\dev_env\Anaconda2\lib\site-packages\pandas\tools\merge.pyc in get_result(self)
#     554
#     555         llabels, rlabels = items_overlap_with_suffix(ldata.items, lsuf,
# --> 556                                                      rdata.items, rsuf)
#     557
#     558         lindexers = {1: left_indexer} if left_indexer is not None else {}
#
# C:\dev_env\Anaconda2\lib\site-packages\pandas\core\internals.pyc in items_overlap_with_suffix(left, lsuffix, right, rsuffix)
#    4697         if not lsuffix and not rsuffix:
#    4698             raise ValueError('columns overlap but no suffix specified: %s' %
# -> 4699                              to_rename)
#    4700
#    4701         def lrenamer(x):
#
# ValueError: columns overlap but no suffix specified: Index([u'crbsa.rb_close'], dtype='object')

# %% [markdown]
# # 夏普比率校验

# %%
config = {"relation": NEGATIVE, "type":UP, "his_count": 12, "std_count":1, "period": 1}

# %%
report = sharp_ratio_test(asset_series=asset_series, 
                             factor_series=factor_series, 
                             event_name="e001", 
                             config=config, lag=1)

# %%
import pandas_highcharts
from pandas_highcharts.display import display_charts
import matplotlib.pyplot as plt
print report['excess_sp']
display_charts(report["ts"][["base","value"]], chart_type="stock", title="CRB 夏普比率测试")
# Out:
# 0.918362503683
# <div id="chart_idMMTWBoxu"</div>
#     <script type="text/javascript">new Highcharts.StockChart({"title":{"text":"CRB \u590f\u666e\u6bd4\u7387\u6d4b\u8bd5"},"series":[{"data":[[1425081600000,1.011985765],[1427760000000,0.9725081964],[1430352000000,0.9936358504],[1433030400000,0.9907372613],[1435622400000,0.9941048194],[1438300800000,1.0067477422],[1440979200000,1.0218281012],[1443571200000,1.0310523604],[1446249600000,1.0504261906],[1448841600000,1.0507694999],[1451520000000,1.0791216812],[1454198400000,1.0804432118],[1456704000000,1.0764425456],[1459382400000,1.0754354648],[1461974400000,1.0608697691],[1464652800000,1.0718382322],[1467244800000,1.0837536518],[1469923200000,1.0939976179],[1472601600000,1.0967843759],[1475193600000,1.1045782796],[1477872000000,1.1076927147],[1480464000000,1.0939693595],[1483142400000,1.066467936],[1485820800000,1.0489290973],[1488240000000,1.0450582995],[1490918400000,1.048193778],[1493510400000,1.0376010914],[1496188800000,1.029247431],[1498780800000,1.0476117755],[1501459200000,1.0511560987],[1504137600000,1.0489345085]],"name":"base","yAxis":0},{"data":[[1425081600000,1.011985765],[1427760000000,0.9725081964],[1430352000000,0.9936358504],[1433030400000,0.9907372613],[1435622400000,0.9941048194],[1438300800000,1.0067477422],[1440979200000,1.0218281012],[1443571200000,1.0310523604],[1446249600000,1.0504261906],[1448841600000,1.0507694999],[1451520000000,1.0791216812],[1454198400000,1.0804432118],[1456704000000,1.0764425456],[1459382400000,1.0754354648],[1461974400000,1.0608697691],[1464652800000,1.0718382322],[1467244800000,1.0718382322],[1469923200000,1.0819695701],[1472601600000,1.0819695701],[1475193600000,1.0896581978],[1477872000000,1.0927305646],[1480464000000,1.0791925775],[1483142400000,1.0520626293],[1485820800000,1.0520626293],[1488240000000,1.0520626293],[1490918400000,1.0520626293],[1493510400000,1.0520626293],[1496188800000,1.0520626293],[1498780800000,1.0708340539],[1501459200000,1.0708340539],[1504137600000,1.0708340539]],"name":"value","yAxis":0}],"yAxis":[{}],"chart":{"renderTo":"chart_idMMTWBoxu"},"xAxis":{"type":"datetime"},"legend":{"enabled":true}});</script>

# %% [markdown]
# # 信号PAE校验

# %% [markdown]
# ## 事件001

# %%
config_e001 = {"relation": NEGATIVE, "type":UP, "his_count": 12, "std_count":2, "period": 1}

# %%
report = perform_after_event(asset_series=asset_series, 
                             factor_series=factor_series, 
                             event_name="e001", 
                             config=config_e001,
                             asset_price=True,lag=1)

# %%
# %matplotlib inline
print u"信息比率:"  + str(report["ir"])
print u"收益均值:" + str(report["ts"]["ret"].mean())
print u"准确率:" + str((report["ts"]["ret"]<0).sum()*1.0/report["ts"]["ret"].count())
print u"事件数:" + str(len(report["ts"]))
print u"占样本比例:" + str(len(report["ts"])*1.0/len(report["origin_ts"])*100) +u"%"
print u"样本上涨概率" + str((report["origin_ts"]["ret"]>0).sum()*1.0/report["origin_ts"]["ret"].count())
report["ts"]
# Out:
# 信息比率:0.199752558856
# 收益均值:0.000371813136957
# 准确率:0.39175257732
# 事件数:97
# 占样本比例:11.0730593607%
# 样本上涨概率0.566210045662
#             crbsa.rb_close       ret
# 2014-02-17        1.091021  0.000202
# 2014-02-19        1.837086  0.000900
# 2014-02-20        1.052691  0.001293
# 2014-02-21        0.532170  0.003731
# 2014-02-25        0.963799  0.002057
# 2014-02-27        2.004359  0.001647
# 2014-03-03        0.861194 -0.004573
# 2014-03-04        0.479736 -0.003806
# 2014-03-05        0.309042 -0.001601
# 2014-03-20        0.003783  0.000424
# 2014-03-21        1.120082 -0.000703
# 2014-03-24        0.079198 -0.000423
# 2014-03-25        1.420831 -0.000571
# 2014-03-26        1.936693  0.000493
# 2014-03-28        0.174366  0.000504
# 2014-04-15        3.380734  0.001176
# 2014-04-16        1.153599  0.005537
# 2014-04-30        0.282657  0.003622
# 2014-05-06        1.293202  0.003934
# 2014-05-07        1.432285  0.004126
# 2014-07-29        0.055915  0.001315
# 2014-08-27        0.080249  0.002632
# 2015-04-28        0.620878  0.000737
# 2015-04-29        1.258911  0.000750
# 2015-04-30        1.309710  0.000154
# 2015-05-04        1.759762 -0.001249
# 2015-05-05        1.469594 -0.001538
# 2015-05-06        0.397993  0.001121
# 2015-05-07        0.477961  0.001111
# 2015-05-11        0.493502  0.001000
# ...                    ...       ...
# 2016-11-10        2.656280 -0.000375
# 2016-11-11        3.166268 -0.001080
# 2016-11-14        0.919082 -0.000488
# 2016-11-24        1.139316 -0.001916
# 2016-11-25        0.322831  0.000472
# 2016-12-01        0.904665 -0.002056
# 2016-12-12        1.139242 -0.003279
# 2017-01-10        3.520229 -0.001469
# 2017-01-11        3.405290 -0.000442
# 2017-01-12        2.102115 -0.000033
# 2017-01-13        0.584720 -0.002500
# 2017-02-09        0.906901 -0.000643
# 2017-02-14        0.280421 -0.000013
# 2017-02-15        0.362105  0.001335
# 2017-02-16        1.652129  0.001222
# 2017-05-02        1.208485 -0.000421
# 2017-05-03        3.455302 -0.002364
# 2017-05-04        1.316368 -0.000174
# 2017-05-16        4.331005  0.000320
# 2017-05-17        1.856818  0.001588
# 2017-06-05        0.609082  0.000355
# 2017-06-09        0.618415  0.004220
# 2017-06-12        3.708334  0.001413
# 2017-06-13        0.975668  0.000958
# 2017-06-14        1.694813  0.000800
# 2017-07-03        1.933830 -0.000081
# 2017-07-04        1.960253  0.001282
# 2017-07-05        0.086983  0.001998
# 2017-08-09        0.810677  0.000526
# 2017-08-10        0.491025  0.002907
#
# [97 rows x 2 columns]

# %% [markdown]
# ## 事件003x2

# %%
config_e003x2 = {"relation": NEGATIVE, "type":UP, "his_count": 3, "threshold": -0.00, "threshold2": 0.01, "period": 1}

# %%
report = perform_after_event(asset_series=asset_series, 
                             factor_series=factor_series, 
                             event_name="e003x2", 
                             config=config_e003x2,
                             asset_price=True)

# %%
# %matplotlib inline
print u"信息比率:"  + str(report["ir"])
print u"收益均值:" + str(report["ts"]["ret"].mean())
print u"准确率:" + str((report["ts"]["ret"]<0).sum()*1.0/report["ts"]["ret"].count())
print u"事件数:" + str(len(report["ts"]))
print u"占样本比例:" + str(len(report["ts"])*1.0/len(report["origin_ts"])*100) +u"%"
print u"样本上涨概率" + str((report["origin_ts"]["ret"]>0).sum()*1.0/report["origin_ts"]["ret"].count())
report["ts"]
# Out:
# 信息比率:nan
# 收益均值:nan
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-59-0a22b5c09bee> in <module>()
#       2 print u"信息比率:"  + str(report["ir"])
#       3 print u"收益均值:" + str(report["ts"]["ret"].mean())
# ----> 4 print u"准确率:" + str((report["ts"]["ret"]<0).sum()*1.0/report["ts"]["ret"].count())
#       5 print u"事件数:" + str(len(report["ts"]))
#       6 print u"占样本比例:" + str(len(report["ts"])*1.0/len(report["origin_ts"])*100) +u"%"
#
# ZeroDivisionError: float division by zero

# %% [markdown]
# ## 事件006

# %%
config_e006 = {"relation": NEGATIVE, "type":UP, "long_count": 180, "short_count":10, "std_count":0, "period": 5}

# %%
report = perform_after_event(asset_series=asset_series, 
                             factor_series=factor_series, 
                             event_name="e006", 
                             config=config_e006,
                             asset_price=True)

# %%
# %matplotlib inline
print u"信息比率:"  + str(report["ir"])
print u"收益均值:" + str(report["ts"]["ret"].mean())
print u"准确率:" + str((report["ts"]["ret"]<0).sum()*1.0/report["ts"]["ret"].count())
print u"事件数:" + str(len(report["ts"]))
print u"占样本比例:" + str(len(report["ts"])*1.0/len(report["origin_ts"])*100) +u"%"
print u"样本上涨概率" + str((report["origin_ts"]["ret"]>0).sum()*1.0/report["origin_ts"]["ret"].count())
report["ts"]
# Out:
# 信息比率:-0.0579824081546
# 收益均值:-0.000303214789128
# 准确率:0.460317460317
# 事件数:63
# 占样本比例:44.6808510638%
# 样本上涨概率0.574468085106
#             crbsa.rb_close       ret
# 2016-03-23        0.767556  0.004522
# 2016-03-30        6.340667 -0.002226
# 2016-04-07        8.119056 -0.004264
# 2016-04-14        9.053111  0.000996
# 2016-04-21       14.540778 -0.006815
# 2016-04-28       20.544056  0.001202
# 2016-05-06       22.075611  0.004002
# 2016-05-13       20.750389 -0.001096
# 2016-05-20       20.738722 -0.000249
# 2016-05-27       19.429278  0.000499
# 2016-06-03       17.267111  0.002044
# 2016-06-14       20.181389  0.002488
# 2016-06-21       23.865000  0.001340
# 2016-06-28       22.449833  0.001289
# 2016-07-05       18.731000  0.000198
# 2016-07-12       16.473278  0.001485
# 2016-07-19       16.445444  0.002718
# 2016-07-26       16.163444  0.000789
# 2016-08-02       13.189056  0.002758
# 2016-08-09       10.440000 -0.000786
# 2016-08-16       10.739278 -0.003097
# 2016-08-23       12.057333 -0.001578
# 2016-08-30       10.967056  0.000099
# 2016-09-06        6.665222  0.001531
# 2016-09-13        3.724000  0.000641
# 2016-09-22        1.108556  0.001478
# 2016-11-17        1.355778  0.001542
# 2016-11-24        4.448889 -0.008545
# 2016-12-01        6.472889 -0.002856
# 2016-12-08        9.984111 -0.019146
# ...                    ...       ...
# 2017-01-06       11.456222  0.001458
# 2017-01-13       13.520111 -0.001105
# 2017-01-20       17.947667 -0.020107
# 2017-02-03       19.451222  0.005643
# 2017-02-10       18.766389  0.005611
# 2017-02-17       19.269222  0.002283
# 2017-02-24       18.887889 -0.003745
# 2017-03-03       17.217667 -0.003150
# 2017-03-10       16.687667  0.007185
# 2017-03-17       16.210944  0.004453
# 2017-03-24       16.240444 -0.000201
# 2017-03-31       15.619611 -0.000907
# 2017-04-11       12.709778 -0.005850
# 2017-04-18        7.919500 -0.001877
# 2017-04-25        3.654833 -0.002338
# 2017-05-03        2.841667 -0.012073
# 2017-05-10        5.345778  0.003300
# 2017-05-17        6.877722 -0.000360
# 2017-05-24        9.447444  0.004164
# 2017-06-02       12.729889 -0.000870
# 2017-06-09       12.528556  0.003126
# 2017-06-16       14.758611  0.001124
# 2017-06-23       17.232333  0.000000
# 2017-06-30       16.289000 -0.000255
# 2017-07-07       17.244667 -0.000970
# 2017-07-14       18.516889 -0.001430
# 2017-07-21       15.780167 -0.002814
# 2017-07-28       12.970778 -0.001180
# 2017-08-04       11.033444  0.001541
# 2017-08-11       10.452556  0.000462
#
# [63 rows x 2 columns]

# %%
report
