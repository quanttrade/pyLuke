# %%
import os
import sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)
from windHelper import WindHelper
from factorModel.factorValidator import *
from datetime import *

# %%
beginDate = datetime(2006, 1, 1)
endDate = datetime(2017, 8, 22)
para = "close"
codeList=["0602E.CS","CRBSA.RB"]
df = WindHelper.getMultiTimeSeriesDataFrame(codeList=codeList, beginDate=beginDate, endDate=endDate, para=para)
df = df.dropna()
df
asset_series = df[(codeList[0]).lower() + "_close"]
factor_series = df[codeList[1] + "_close"]
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-4711905f0857> in <module>()
#       6 df = df.dropna()
#       7 df
# ----> 8 asset_series = df[lower(codeList[0]) + "_close"]
#       9 factor_series = df[codeList[1] + "_close"]
#      10 df.head()
#
# NameError: name 'lower' is not defined

# %% [markdown]
# # 观察7-10年国开净价和CRB的关系

# %%
# %matplotlib inline
df["crbsa.rb_close"].rolling_mean(window=60)
# df.plot(secondary_y='crbsa.rb_close')
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-ceaaf848e0d9> in <module>()
#       1 get_ipython().magic(u'matplotlib inline')
# ----> 2 df["crbsa.rb_close"].rolling_mean(window=60)
#       3 # df.plot(secondary_y='crbsa.rb_close')
#       4 df
#
# C:\dev_env\Anaconda2\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'rolling_mean'

# %%
import pandas_highcharts
from pandas_highcharts.display import display_charts
import matplotlib.pyplot as plt
display_charts(df, chart_type="stock",secondary_y='crbsa.rb_close', title="CRB测试")
# Out:
# <div id="chart_idAANRZMxF"</div>
#     <script type="text/javascript">new Highcharts.StockChart({"title":{"text":"CRB\u6d4b\u8bd5"},"series":[{"data":[[1136332800000,115.1306],[1136419200000,114.2166],[1136505600000,115.4616],[1136764800000,115.3361],[1136851200000,115.3983],[1136937600000,115.4205],[1137024000000,116.0074],[1137110400000,116.1189],[1137369600000,115.8434],[1137456000000,116.2732],[1137542400000,116.5736],[1137628800000,116.504],[1137715200000,116.566],[1137974400000,116.1916],[1138060800000,115.7956],[1138147200000,116.4252],[1139184000000,116.2479],[1139270400000,116.3093],[1139356800000,116.0101],[1139443200000,116.4344],[1139529600000,116.4745],[1139788800000,116.4458],[1139875200000,116.0203],[1139961600000,115.5287],[1140048000000,115.3697],[1140134400000,115.6598],[1140393600000,115.9113],[1140480000000,115.498],[1140566400000,115.8782],[1140652800000,115.979],[1140739200000,115.1822],[1140998400000,116.2951],[1141084800000,115.9665],[1141171200000,116.5418],[1141257600000,116.4711],[1141344000000,116.6305],[1141603200000,116.9619],[1141689600000,116.8001],[1141776000000,116.401],[1141862400000,117.3656],[1141948800000,117.0042],[1142208000000,117.0555],[1142294400000,117.1238],[1142380800000,117.4061],[1142467200000,117.1223],[1142553600000,117.0958],[1142812800000,117.1345],[1142899200000,116.9693],[1142985600000,117.25],[1143072000000,117.4018],[1143158400000,117.485],[1143417600000,117.498],[1143504000000,117.4377],[1143590400000,117.3985],[1143676800000,117.351],[1143763200000,117.3843],[1144022400000,117.3047],[1144108800000,117.4862],[1144195200000,117.3535],[1144281600000,117.3019],[1144368000000,117.106],[1144627200000,117.5832],[1144713600000,117.22],[1144800000000,117.1553],[1144886400000,117.0945],[1144972800000,116.774],[1145232000000,117.0448],[1145318400000,116.7752],[1145404800000,116.6997],[1145491200000,116.6481],[1145577600000,116.997],[1145836800000,116.9823],[1145923200000,116.921],[1146009600000,116.6557],[1146096000000,116.5877],[1146182400000,116.9871],[1147046400000,116.2892],[1147132800000,116.6839],[1147219200000,116.6843],[1147305600000,116.6254],[1147392000000,116.224],[1147651200000,116.5678],[1147737600000,116.4503],[1147824000000,116.4246],[1147910400000,116.4917],[1147996800000,116.4406],[1148256000000,116.6906],[1148342400000,116.6919],[1148428800000,116.6334],[1148515200000,116.7345],[1148601600000,116.5245],[1148860800000,116.5156],[1148947200000,116.0354],[1149033600000,116.7018],[1149120000000,116.6476],[1149206400000,116.4312],[1149465600000,116.4057],[1149552000000,116.5434],[1149638400000,116.0927],[1149724800000,116.2385],[1149811200000,116.2613],[1150070400000,116.1874],[1150156800000,115.7416],[1150243200000,116.2572],[1150329600000,116.0928],[1150416000000,114.9957],[1150675200000,115.0032],[1150761600000,115.4225],[1150848000000,114.8239],[1150934400000,114.5839],[1151020800000,114.8677],[1151280000000,114.8371],[1151366400000,115.21],[1151452800000,114.7593],[1151539200000,114.961],[1151625600000,114.9504],[1151884800000,114.9125],[1151971200000,115.2632],[1152057600000,114.9481],[1152144000000,114.8949],[1152230400000,114.7708],[1152489600000,115.1143],[1152576000000,115.342],[1152662400000,115.2129],[1152748800000,115.5355],[1152835200000,115.1229],[1153094400000,115.2521],[1153180800000,115.6039],[1153267200000,115.066],[1153353600000,114.8627],[1153440000000,114.9028],[1153699200000,114.6935],[1153785600000,114.7768],[1153872000000,114.5942],[1153958400000,114.7877],[1154044800000,114.5698],[1154304000000,114.6937],[1154390400000,113.996],[1154476800000,114.47],[1154563200000,114.3984],[1154649600000,114.4074],[1154908800000,114.715],[1154995200000,114.4726],[1155081600000,114.6257],[1155168000000,115.0273],[1155254400000,114.6641],[1155513600000,114.6764],[1155600000000,114.8314],[1155686400000,114.8822],[1155772800000,115.2779],[1155859200000,115.5237],[1156118400000,115.2923],[1156204800000,114.9598],[1156291200000,115.4073],[1156377600000,115.6328],[1156464000000,115.4441],[115672320 ...

# %% [markdown]
# # 夏普比率校验

# %%
config = {"relation": NEGATIVE, "type":UP, "his_count": 60,"std_count":0, "period": 5}

# %%
report = sharp_ratio_test(asset_series=asset_series, 
                             factor_series=factor_series, 
                             event_name="e001", 
                             config=config)

# %%
import pandas_highcharts
from pandas_highcharts.display import display_charts
import matplotlib.pyplot as plt
print report['excess_sp']
display_charts(report["ts"][["base","value"]], chart_type="stock", title="CRB 夏普比率测试")
# Out:
# -0.430049818302
# <div id="chart_idmPtBZtNo"</div>
#     <script type="text/javascript">new Highcharts.StockChart({"title":{"text":"CRB \u590f\u666e\u6bd4\u7387\u6d4b\u8bd5"},"series":[{"data":[[1144627200000,1.0040749407],[1144713600000,1.000973477],[1144800000000,1.0004209861],[1144886400000,0.9999017984],[1144972800000,0.9971649617],[1145232000000,0.9994773965],[1145318400000,0.9971752088],[1145404800000,0.9965304937],[1145491200000,0.9960898673],[1145577600000,0.9990692193],[1145836800000,0.998943692],[1145923200000,0.9984202347],[1146009600000,0.9961547658],[1146096000000,0.9955740953],[1146182400000,0.9989846805],[1147046400000,0.9930251225],[1147132800000,0.9963955732],[1147219200000,0.996398989],[1147305600000,0.9958960258],[1147392000000,0.992468362],[1147651200000,0.9954041637],[1147737600000,0.9944007993],[1147824000000,0.99418134],[1147910400000,0.9947543251],[1147996800000,0.9943179683],[1148256000000,0.9964527864],[1148342400000,0.9964638874],[1148428800000,0.99596434],[1148515200000,0.9968276604],[1148601600000,0.9950344133],[1148860800000,0.9949584137],[1148947200000,0.9908578553],[1149033600000,0.9965484262],[1149120000000,0.9960855977],[1149206400000,0.9942376992],[1149465600000,0.9940199477],[1149552000000,0.9951958055],[1149638400000,0.9913471556],[1149724800000,0.9925921814],[1149811200000,0.9927868768],[1150070400000,0.9921558246],[1150156800000,0.9883490171],[1150243200000,0.9927518658],[1150329600000,0.9913480095],[1150416000000,0.9819795741],[1150675200000,0.9820436186],[1150761600000,0.9856241354],[1150848000000,0.9805125271],[1150934400000,0.9784631018],[1151020800000,0.9808865472],[1151280000000,0.9806252455],[1151366400000,0.9838095401],[1151452800000,0.9799608901],[1151539200000,0.9816832613],[1151625600000,0.981592745],[1151884800000,0.9812691066],[1151971200000,0.9842638294],[1152057600000,0.9815731047],[1152144000000,0.9811188154],[1152230400000,0.9800590918],[1152489600000,0.9829923317],[1152576000000,0.984936724],[1152662400000,0.983834304],[1152748800000,0.9865890731],[1152835200000,0.9830657695],[1153094400000,0.9841690434],[1153180800000,0.9871731594],[1153267200000,0.9825798849],[1153353600000,0.9808438509],[1153440000000,0.9811862757],[1153699200000,0.979399006],[1153785600000,0.9801103274],[1153872000000,0.9785510563],[1153958400000,0.9802034055],[1154044800000,0.9783426981],[1154304000000,0.9794007139],[1154390400000,0.9734428637],[1154476800000,0.9774904787],[1154563200000,0.9768790668],[1154649600000,0.9769559203],[1154908800000,0.9795826004],[1154995200000,0.9775126808],[1155081600000,0.9788200434],[1155168000000,0.9822494151],[1155254400000,0.9791479514],[1155513600000,0.9792529845],[1155600000000,0.9805765717],[1155686400000,0.9810103667],[1155772800000,0.9843893567],[1155859200000,0.9864883097],[1156118400000,0.9845123222],[1156204800000,0.9816730142],[1156291200000,0.9854943385],[1156377600000,0.9874199443],[1156464000000,0.9858085837],[1156723200000,0.9898613222],[1156809600000,0.9883490171],[1156896000000,0.990344645],[1156982400000,0.9899783102],[1157068800000,0.99012177],[1157328000000,0.9909210459],[1157414400000,0.9901183543],[1157500800000,0.9907895411],[1157587200000,0.9902216795],[1157673600000,0.989980872],[1157932800000,0.9913514252],[1158019200000,0.9906426656],[1158105600000,0.9928543371],[1158192000000,0.9927740679],[1158278400000,0.9931455263],[1158537600000,0.9949951326],[1158624000000,0.9964673031],[1158710400000,0.9987028846],[1158796800000,1.0005405359],[1158883200000,1.00086759],[1159142400000,1.0062755111],[1159228800000,1.0033166533],[1159315200000,1.0061482759],[1159401600000,1.0058716035],[1159488000000,1.0093786826],[1160352000000,1.0080055676],[1160438400000,1.0070884498],[1160524800000,1.0081985552],[1160611200000,1.0084666883],[1160697600000,1.0075837276],[1160956800000,1.0074189196],[1161043200000,1.0089226854],[1161129600000,1.0102445648],[1161216000000,1.0095998497],[1161302400000,1.0101566103],[1161561600000,1.0115937697],[1161648000000,1.0110711663],[1161734400000,1.0108781787],[1161820800000,1.014 ...

# %% [markdown]
# # 信号PAE校验

# %% [markdown]
# 重新检视配置文件

# %%
config = {"period": 22, "relation": NEGATIVE, "type":UP, "his_count": 60,"std_count":2}

# %%
report = perform_after_event(asset_series=asset_series, 
                             factor_series=factor_series, 
                             event_name="e001", 
                             config=config,
                             asset_price=True)

# %%
# %matplotlib inline
report["ts"]["ret"]
# Out:
# 2006-04-10   -0.009853
# 2006-05-17   -0.012273
# 2007-03-08    0.001237
# 2008-03-05    0.008529
# 2009-08-10    0.003192
# 2009-11-18    0.002599
# 2010-08-06    0.003625
# 2011-01-20   -0.001990
# 2014-02-27   -0.008854
# 2016-03-23   -0.021993
# 2016-04-25    0.016996
# 2016-12-09   -0.013456
# Name: ret, dtype: float64

# %%
len(report["ts"]["ret"][report["ts"]["ret"]<0])*1.0/len(report["ts"]["ret"])
